# %%
import rasterio
import os
import numpy as np
import glob
from PIL import Image

# %%
image_1 = "/data/integracar/amostras_car/ES-3201605-6D3B7D2F0DA54E37A1DB8D30B9D72C9E.tif"

# %%
Image.open(image_1).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
rasterio.open(image_1).read()
# Out:
# array([[[178, 178, 178, ..., 207, 207, 207],
#         [178, 178, 178, ..., 207, 207, 207],
#         [178, 178, 178, ..., 207, 207, 207],
#         ...,
#         [178, 178, 178, ..., 207, 207, 207],
#         [178, 178, 178, ..., 207, 207, 207],
#         [178, 178, 178, ..., 207, 207, 207]],
#
#        [[214, 214, 214, ..., 103, 103, 103],
#         [214, 214, 214, ..., 103, 103, 103],
#         [214, 214, 214, ..., 103, 103, 103],
#         ...,
#         [214, 214, 214, ..., 103, 103, 103],
#         [214, 214, 214, ..., 103, 103, 103],
#         [214, 214, 214, ..., 103, 103, 103]],
#
#        [[ 32,  32,  32, ...,  65,  65,  65],
#         [ 32,  32,  32, ...,  65,  65,  65],
#         [ 32,  32,  32, ...,  65,  65,  65],
#         ...,
#         [ 32,  32,  32, ...,  65,  65,  65],
#         [ 32,  32,  32, ...,  65,  65,  65],
#         [ 32,  32,  32, ...,  65,  65,  65]],
#
#        [[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
# ...
